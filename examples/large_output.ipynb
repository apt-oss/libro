# %%
from tqdm import tqdm
import time
for epoch in tqdm(range(100), desc="Epoch", position=0):
    time.sleep(0.1)
# Out:
# Epoch: 100%|██████████████████████████████████| 100/100 [00:10<00:00,  9.43it/s]

# %%
from IPython.display import display
from IPython.display import (
    HTML, Image, Latex, Math, Markdown, SVG
)
for i in range (0, 50): 
    epoch = i
    batch_idx = i % 100
    time.sleep(0.01)
    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: 2.797897966'.format(
        epoch, batch_idx * 100, 1000,
        100. * batch_idx / 1000))
div = HTML('<div style="width:100px;height:100px;background:grey;" />')
div
for i in range(30):  # 调整范围控制输出量
    # warnings.warn(f"{long_text} [Iteration {i}]")
    print("test")
# Out:
# Train Epoch: 0 [0/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 1 [100/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 2 [200/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 3 [300/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 4 [400/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 5 [500/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 6 [600/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 7 [700/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 8 [800/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 9 [900/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 10 [1000/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 11 [1100/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 12 [1200/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 13 [1300/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 14 [1400/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 15 [1500/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 16 [1600/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 17 [1700/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 18 [1800/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 19 [1900/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 20 [2000/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 21 [2100/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 22 [2200/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 23 [2300/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 24 [2400/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 25 [2500/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 26 [2600/1000 (3%)]	Loss: 2.797897966
# Train Epoch: 27 [2700/1000 (3%)]	Loss: 2.797897966
# Train Epoch: 28 [2800/1000 (3%)]	Loss: 2.797897966
# Train Epoch: 29 [2900/1000 (3%)]	Loss: 2.797897966
# Train Epoch: 30 [3000/1000 (3%)]	Loss: 2.797897966
# Train Epoch: 31 [3100/1000 (3%)]	Loss: 2.797897966
# Train Epoch: 32 [3200/1000 (3%)]	Loss: 2.797897966
# Train Epoch: 33 [3300/1000 (3%)]	Loss: 2.797897966
# Train Epoch: 34 [3400/1000 (3%)]	Loss: 2.797897966
# Train Epoch: 35 [3500/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 36 [3600/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 37 [3700/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 38 [3800/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 39 [3900/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 40 [4000/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 41 [4100/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 42 [4200/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 43 [4300/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 44 [4400/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 45 [4500/1000 (4%)]	Loss: 2.797897966
# Train Epoch: 46 [4600/1000 (5%)]	Loss: 2.797897966
# Train Epoch: 47 [4700/1000 (5%)]	Loss: 2.797897966
# Train Epoch: 48 [4800/1000 (5%)]	Loss: 2.797897966
# Train Epoch: 49 [4900/1000 (5%)]	Loss: 2.797897966
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test

# %%
div = HTML('<div style="width:100px;height:100px;background:grey;" />')
print(div)
# Out:
# <IPython.core.display.HTML object>

# %%
# for i in range (0, 50): 
#     epoch = i
#     batch_idx = i % 100
#     time.sleep(0.1)
#     print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: 2.797897966'.format(
#         epoch, batch_idx * 100, 1000,
#         100. * batch_idx / 1000))
from tqdm import tqdm
for i in range(50):  # 调整范围控制输出量
    # warnings.warn(f"{long_text} [Iteration {i}]")
    print("test")
for epoch in tqdm(range(100), desc="Epoch", position=0):
    time.sleep(0.1)
for i in range(12):  # 调整范围控制输出量
    print("test")
div
for i in range(30):  # 调整范围控制输出量
    # warnings.warn(f"{long_text} [Iteration {i}]")
    print("a")
# Out:
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# Epoch: 100%|██████████████████████████████████| 100/100 [00:10<00:00,  9.46it/s]
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a

# %%
# 生成大量警告
for i in range(50):  # 调整范围控制输出量
    # warnings.warn(f"{long_text} [Iteration {i}]")
    print("test")
import sys; print('this is stderr', file=sys.stderr)
for epoch in tqdm(range(100), desc="Epoch", position=0):
    time.sleep(0.1)

# %%
from tqdm import tqdm
import time
for i in range (0, 50): 
    epoch = i
    batch_idx = i % 100
    time.sleep(0.1)
    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: 2.797897966'.format(
        epoch, batch_idx * 100, 1000,
        100. * batch_idx / 1000))

# %%
import time
for i in range (0, 500): 
    epoch = i
    batch_idx = i % 100
    time.sleep(0.1)
    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: 2.797897966'.format(
        epoch, batch_idx * 100, 1000,
        100. * batch_idx / 1000))

# %%
import warnings
import sys

# 允许所有警告重复显示
warnings.simplefilter('always')
import time

# 生成超长文本模板
long_text = "WARNING: This is a very long warning message that will be repeated multiple times. " *2

# 显示控制（可选）：防止输出被截断
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# 生成大量警告
for i in range(50):  # 调整范围控制输出量
    # warnings.warn(f"{long_text} [Iteration {i}]")
    print("test")
for i in range(50):  # 调整范围控制输出量
    warnings.warn(f"{long_text} [Iteration {i}]")
    print("a")
for epoch in tqdm(range(100), desc="Epoch", position=0):
    time.sleep(0.1)
from tqdm import tqdm
import time
for i in range (0, 50): 
    epoch = i
    batch_idx = i % 100
    time.sleep(0.1)
    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: 2.797897966'.format(
        epoch, batch_idx * 100, 1000,
        100. * batch_idx / 1000))
# Out:
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 0]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 1]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 2]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 3]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 4]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 5]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 6]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 7]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 8]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 9]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 10]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 11]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 12]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 13]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 14]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 15]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 16]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 17]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 18]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 19]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 20]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 21]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 22]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 23]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 24]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 25]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 26]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 27]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 28]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 29]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 30]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 31]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 32]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 33]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 34]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 35]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 36]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 37]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 38]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 39]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 40]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 41]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 42]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 43]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 44]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 45]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 46]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 47]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 48]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_3191/1445235886.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 49]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# Epoch: 100%|██████████████████████████████████| 100/100 [00:10<00:00,  9.49it/s]
# Train Epoch: 0 [0/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 1 [100/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 2 [200/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 3 [300/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 4 [400/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 5 [500/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 6 [600/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 7 [700/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 8 [800/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 9 [900/1000 (1%)]	Loss: 2.797897966
