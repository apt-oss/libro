# %%
## test

# %%
from IPython.display import display
from IPython.display import (
    HTML, Image, Latex, Math, Markdown, SVG
)
import time
for i in range (0, 50): 
    epoch = i
    batch_idx = i % 100
    time.sleep(0.01)
    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: 2.797897966'.format(
        epoch, batch_idx * 100, 1000,
        100. * batch_idx / 1000))
div = HTML('<div style="width:100px;height:100px;background:grey;" />')
div
for i in range(30):  # 调整范围控制输出量
    # warnings.warn(f"{long_text} [Iteration {i}]")
    print("test")
# Out:
# Train Epoch: 0 [0/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 1 [100/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 2 [200/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 3 [300/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 4 [400/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 5 [500/1000 (0%)]	Loss: 2.797897966
# Train Epoch: 6 [600/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 7 [700/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 8 [800/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 9 [900/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 10 [1000/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 11 [1100/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 12 [1200/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 13 [1300/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 14 [1400/1000 (1%)]	Loss: 2.797897966
# Train Epoch: 15 [1500/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 16 [1600/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 17 [1700/1000 (2%)]	Loss: 2.797897966
# Train Epoch: 18 [1800/1000 (2%)]	Loss: 2.797897966
# ...

# %% [markdown]
# ## test

# %%
import warnings
import sys
from tqdm import tqdm
# 允许所有警告重复显示
warnings.simplefilter('always')
import time

# 生成超长文本模板
long_text = "WARNING: This is a very long warning message that will be repeated multiple times. " *2

# 显示控制（可选）：防止输出被截断
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# 生成大量警告
for i in range(50):  # 调整范围控制输出量
    # warnings.warn(f"{long_text} [Iteration {i}]")
    print("test")
for i in range(50):  # 调整范围控制输出量
    warnings.warn(f"{long_text} [Iteration {i}]")
    print("a")
for epoch in tqdm(range(100), desc="Epoch", position=0):
    time.sleep(0.1)
from tqdm import tqdm
import time
for i in range (0, 50): 

    epoch = i
    batch_idx = i % 100
    time.sleep(0.1)
    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: 2.797897966'.format(
        epoch, batch_idx * 100, 1000,
        100. * batch_idx / 1000))
# Out:
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_40210/3910230480.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 0]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_40210/3910230480.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 1]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# /var/folders/1m/1c2plsgx7rd9cx947fdd5t7w0000gp/T/ipykernel_40210/3910230480.py:20: UserWarning: WARNING: This is a very long warning message that will be repeated multiple times. WARNING: This is a very long warning message that will be repeated multiple times.  [Iteration 2]
#   warnings.warn(f"{long_text} [Iteration {i}]")
# ...
